# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_loading = pd.read_csv('Part3_loading_time.txt', sep=",", header=None)
data_loading.columns = ['n','time']

# %%
data_loading.head()
# Out:
#      n  time
# 0   10   925
# 1   50   906
# 2  100   854
# 3  150   845
# 4  200   807

# %%
data_loading.plot.line(x="n",y='time')
plt.title("loading time w.r.t. n")
plt.legend();

# %%
data_knn_k = pd.read_csv('avg_execution_time_k.txt', sep=",", header=None)
data_knn_k.columns = ['n','time']
data_knn_k.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_r_k = pd.read_csv('avg_execution_time_RTree_k.txt', sep=",", header=None)
data_r_k.columns = ['n','time']
data_r_k.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_r_n = pd.read_csv('avg_execution_time_RTree_n.txt', sep=",", header=None)
data_r_n.columns = ['n','time']
data_r_n.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_linear = pd.read_csv('avg_execution_time_linear_n.txt', sep=",", header=None)
data_linear.columns = ['n','time']
data_linear.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_linear_k = pd.read_csv('avg_execution_time_linear_k.txt', sep=",", header=None)
data_linear_k.columns = ['n','time']
data_linear_k.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_efficient_k = pd.read_csv('avg_execution_time_efficient_k.txt', sep=",", header=None)
data_efficient_k.columns = ['n','time']
data_efficient_k.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
data_load = pd.read_csv('loading_time.txt', sep=",", header=None)
data_load.columns = ['n','time']
data_load.plot.line(x="n",y='time')
# Out:
# <AxesSubplot:xlabel='n'>

# %%
plt.plot(data_knn_k.iloc[:, 0],data_knn_k.iloc[:, 1], label = "knn")
# plt.plot(data_linear.iloc[:, 0],data_linear.iloc[:, 1]*1000000, label = "linear")
plt.plot(data_efficient_k.iloc[:, 0],data_efficient_k.iloc[:, 1], label = "knn_fast")
plt.legend()
plt.title("knn vs. knn_fast")
plt.xlabel("k")
# Out:
# Text(0.5, 0, 'k')

# %%
data_efficient_n = pd.read_csv('avg_execution_time_efficient_n.txt', sep=",", header=None)
data_efficient_n.columns = ['n','time']

data_knn_n = pd.read_csv('avg_execution_time_n.txt', sep=",", header=None)
data_knn_n.columns = ['n','time']

plt.plot(data_knn_n.iloc[:, 0],data_knn_n.iloc[:, 1], label = "knn")
# plt.plot(data_linear.iloc[:, 0],data_linear.iloc[:, 1], label = "linear")
plt.plot(data_efficient_n.iloc[:, 0],data_efficient_n.iloc[:, 1], label = "efficient")
plt.legend()
plt.title("knn vs. knn_fast")
plt.xlabel("n")
# Out:
# Text(0.5, 0, 'n')

# %%
data_efficient_n = pd.read_csv('avg_execution_time_efficient_n.txt', sep=",", header=None)
data_efficient_n.columns = ['n','time']

data_knn_n = pd.read_csv('avg_execution_time_n.txt', sep=",", header=None)
data_knn_n.columns = ['n','time']

plt.plot(data_knn_n.iloc[:, 0],data_knn_n.iloc[:, 1], label = "knn")
plt.plot(data_linear.iloc[:, 0],data_linear.iloc[:, 1], label = "linear")
plt.plot(data_efficient_n.iloc[:, 0],data_efficient_n.iloc[:, 1], label = "knn_fast")
plt.legend()
plt.title("knn vs. linear vs. knn_fast")
plt.xlabel("n")
# Out:
# Text(0.5, 0, 'n')

# %%
plt.plot(data_knn_k.iloc[:, 0],data_knn_k.iloc[:, 1], label = "knn")
plt.plot(data_linear_k.iloc[:, 0],data_linear_k.iloc[:, 1], label = "linear")
plt.plot(data_efficient_k.iloc[:, 0],data_efficient_k.iloc[:, 1], label = "knn_fast")
plt.legend()
plt.title("knn vs. knn_fast vs. linear")
plt.xlabel("k")
# Out:
# Text(0.5, 0, 'k')

# %%
plt.plot(data_knn_k.iloc[:, 0],data_knn_k.iloc[:, 1], label = "knn")
# plt.plot(data_linear_k.iloc[:, 0],data_linear_k.iloc[:, 1], label = "linear")
plt.plot(data_efficient_k.iloc[:, 0],data_efficient_k.iloc[:, 1], label = "knn_fast")
plt.legend()
plt.title("knn vs. knn_fast")
plt.xlabel("k")
# Out:
# Text(0.5, 0, 'k')

# %%
plt.plot(data_knn_k.iloc[:, 0],data_knn_k.iloc[:, 1], label = "knn")
plt.plot(data_linear_k.iloc[:, 0],data_linear_k.iloc[:, 1], label = "linear")
plt.plot(data_efficient_k.iloc[:, 0],data_efficient_k.iloc[:, 1], label = "knn_fast")
plt.plot(data_r_k.iloc[:, 0],data_r_k.iloc[:, 1], label = "RTree")
plt.legend()
plt.title("knn vs. knn_fast vs. RTree vs. linear")
plt.xlabel("k")
# Out:
# Text(0.5, 0, 'k')

# %%
plt.plot(data_knn_n.iloc[:, 0],data_knn_n.iloc[:, 1], label = "knn")
plt.plot(data_linear.iloc[:, 0],data_linear.iloc[:, 1], label = "linear")
plt.plot(data_efficient_n.iloc[:, 0],data_efficient_n.iloc[:, 1], label = "knn_fast")
plt.plot(data_r_n.iloc[:, 0],data_r_n.iloc[:, 1], label = "RTree")
plt.legend()
plt.title("knn vs. linear vs. knn_fast vs. RTree")
plt.xlabel("n")
# Out:
# Text(0.5, 0, 'n')
